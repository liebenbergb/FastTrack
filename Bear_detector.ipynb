# %% [markdown]
# <a href="https://colab.research.google.com/github/liebenbergb/FastTrack/blob/master/Bear_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The first line, "#hide", is a comment that tells the Jupyter notebook to hide the output of this cell. This is useful for code that is used to set up the environment or install dependencies, as the output of this code is not usually relevant to the user.
#
# The second line, ! [ -e /content ] && pip install -Uqq fastbook, uses the ! character to execute a shell command. The command checks if the directory /content exists. If it does not exist, the command installs the Fastbook library using the pip package manager. The -U flag tells pip to update the library to the latest version. The -q flag tells pip to be quiet, so that the user is not bombarded with output.
#
# The third line, import fastbook, imports the Fastbook library into the current Jupyter notebook environment.
#
# The fourth line, fastbook.setup_book(), calls the setup_book() function from the Fastbook library. This function sets up the environment for using Fastbook, including downloading the necessary data and creating a configuration file.

# %%
#hide
! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# The first line, "#hide", is a comment that tells the Jupyter notebook to hide the output of this cell. This is useful for code that is used to import libraries, as the output of this code is not usually relevant to the user.
#
# The second line, from fastbook import *, imports all of the functions and classes from the Fastbook library into the current Jupyter notebook environment. This means that you can use these functions and classes without having to specify their full names.
#
# The third line, from fastai.vision.widgets import *, imports all of the functions and classes from the Fastai.Vision.Widgets library into the current Jupyter notebook environment. This means that you can use these functions and classes without having to specify their full names.

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# The os module provides a number of functions for interacting with the operating system. Some of the most common functions in the os module include:
#
# os.getcwd(): Get the current working directory.
# os.chdir(): Change the current working directory.
# os.listdir(): List the contents of a directory.
# os.mkdir(): Create a directory.
# os.rmdir(): Remove a directory.
# os.stat(): Get information about a file or directory.
# os.open(): Open a file.
# os.read(): Read data from a file.
# os.write(): Write data to a file.
# os.close(): Close a file.

# %%
import os

# %% [markdown]
# Bing search API key

# %% [markdown]
# The os.environ module provides a dictionary-like interface to the environment variables of the current process. The get() method of the os.environ module takes a key as its first argument and a default value as its second argument. If the environment variable with the given key is set, the value of the environment variable is returned. Otherwise, the default value is returned.
#
# In this case, the environment variable AZURE_SEARCH_KEY is used to store the key for an Azure Search service. If the environment variable is set, the key is used to connect to the Azure Search service. Otherwise, the default key is used.

# %%
key = os.environ.get('AZURE_SEARCH_KEY', '60aab857e7c044deb4017816caffe132')

# %% [markdown]
# The code search_images_bing is a function that searches for images on the Bing image search engine. The function takes three arguments:
#
# key: The Azure Search key for the Bing image search service.
# term: The search term.
# max_images: The maximum number of images to return.
# The function returns a list of URLs for the images that were found.
#
# The function works by making a request to the Bing image search API. The request includes the search term and the maximum number of images to return. The API returns a list of images that match the search term. The function then converts the list of images to a list of URLs and returns the list of URLs.

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing(key, term, min_sz=128, max_images=150)>

# %% [markdown]
# The code results = search_images_bing(key, 'grizzly bear') calls the search_images_bing function to search for images of grizzly bears on the Bing image search engine. The function returns a list of URLs for the images that were found.
#
# The code ims = results.attrgot('contentUrl') assigns the list of URLs to the variable ims.
#
# The code len(ims) returns the length of the list of URLs.

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('contentUrl')
len(ims)
# Out:
# 149

# %% [markdown]
# The search_images_bing() function returns a list of objects that represent the images that were found. Each object has a contentUrl property, which contains the URL of the image. The code uses the attrgot() method to get the contentUrl property of each object and stores it in a list called ims.

# %%
#hide
ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %% [markdown]
# The code then loops through the list of ims and downloads each image to a file. The download_url() function takes two arguments: the URL of the image and the path to the file that you want to save it to. In this case, the path to the file is images/grizzly.jpg.

# %%
dest = 'images/grizzly.jpg'
download_url(ims[0], dest)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='704512' class='' max='697626' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.99% [704512/697626 00:00&lt;00:00]
#     </div>
# Path('images/grizzly.jpg')

# %% [markdown]
# The code then resizes the images to 128x128 pixels. The Image.open() function opens an image file and returns an object that represents the image. The to_thumb() method resizes the image and returns a new image object.

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=108x128>

# %%
bear_types = 'grizzly','black','teddy'
path = Path('bears')

# %% [markdown]
# The code finally loops through a list of bear types and downloads images of each type. The list of bear types is bear_types and it contains the strings "grizzly", "black", and "teddy". For each bear type, the code creates a directory and downloads images of that type to the directory.

# %%
if not path.exists():
    path.mkdir()
    for o in bear_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bear')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %% [markdown]
# uses the get_image_files() function to get a list of all the image files in the specified directory. The get_image_files() function takes one argument, which is the path to the directory. In this case, the path is path.
#
# The code then prints the list of image files. The print() function takes one argument, which is the object that you want to print. In this case, the object is the list of image files.

# %%
fns = get_image_files(path)
fns
# Out:
# (#432) [Path('bears/black/6a740f3c-da9d-416a-bcb5-b2497af86cc9.jpg'),Path('bears/black/cd71a0f6-6e74-4bb5-9e1b-fd2116a788f2.jpg'),Path('bears/black/eb76cc06-b72f-4734-9a54-1ad462b937d5.jpg'),Path('bears/black/72b9082f-10d8-4b62-b436-b2126e6e1006.jpg'),Path('bears/black/b540531c-1899-46f5-9020-8830246414c7.jpg'),Path('bears/black/0d714d31-ace4-431a-80cd-a29d7bb5af69.jpg'),Path('bears/black/d9e98471-8d97-445b-93fe-295f141271c9.jpg'),Path('bears/black/52850238-15e6-491d-b2c7-a2238692aebe.jpg'),Path('bears/black/6d5fdad4-ecc3-49a4-925b-0a7c42063081.jpg'),Path('bears/black/53df9efa-2dd8-4ae8-81ac-212dbd387d07.jpg')...]

# %% [markdown]
# uses the verify_images() function to verify that all of the image files in the specified directory are valid. The verify_images() function takes one argument, which is a list of image file paths. In this case, the list of image file paths is fns.
#
# The code then prints the list of image files that failed verification. The print() function takes one argument, which is the object that you want to print. In this case, the object is the list of image files that failed verification.

# %%
failed = verify_images(fns)
failed
# Out:
# (#17) [Path('bears/black/f761aea4-b530-4aa3-a7c2-dbcbc753986f.jpg'),Path('bears/black/09288320-6397-41fc-9160-a5d70cafdaa4.jpg'),Path('bears/teddy/5c6a9383-d041-49a7-815f-512a880dd1ae.jpg'),Path('bears/teddy/7f6a7444-f2ff-4b78-b97e-a80a537ab1dc.jpg'),Path('bears/teddy/e22d0510-bbc6-4261-b921-cf7a797658f4.JPG'),Path('bears/teddy/995e53f7-606e-4df2-b709-6281e7362f7f.JPG'),Path('bears/teddy/6b141e21-b6b2-49c3-a297-2b6e674f19ef.JPG'),Path('bears/teddy/53de981a-f0f2-47cf-9c6c-06e3e846f6f6.JPG'),Path('bears/teddy/497625b6-e8b1-4bde-ba87-64363a383f97.jpg'),Path('bears/teddy/38b8db84-0878-4287-ad8a-182d959ed100.JPG')...]

# %% [markdown]
# uses the map() function to iterate over the list of image files that failed verification and delete them. The map() function takes two arguments: a function and a list. In this case, the function is the Path.unlink() function and the list is failed.
#
# The Path.unlink() function takes one argument, which is the path to the file that you want to delete. In this case, the path to the file is the image file that failed verification.

# %%
failed.map(Path.unlink);

# %%
bears = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = bears.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = bears.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
bears = bears.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = bears.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)
